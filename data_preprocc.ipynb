# %%
import pandas as pd
data=pd.read_csv('grocery_chain.csv')
data.head()
# Out:
#    customer_id        store_name transaction_date              aisle  \
# 0         5216  QuickStop Market       2020-11-11             Bakery
# 1         6173  QuickStop Market       2025-11-17            Produce
# 2         8973  ValuePlus Market       2022-03-28  Health & Wellness
# 3         4197  City Fresh Store       2021-10-28    Household Items
# 4         4666  QuickStop Market       2025-05-10       Canned Goods
#
#    product_name  quantity  unit_price  total_amount  discount_amount  \
# 0        Cereal         3        4.06         12.18             1.14
# 1   Ground Beef         3        8.70         26.10             0.52
# 2  Orange Juice         1        4.26          4.26             0.14
# 3        Apples         2        2.28          4.56             0.66
# 4          Eggs         3        3.39         10.17             0.92
#
#    final_amount  loyalty_points
# 0         11.04             299
# 1         25.58             266
# 2          4.12             317
# ...

# %%
data.groupby("product_name")["aisle"].nunique().sort_values(ascending=False)
# Out:
# product_name
# Apples          11
# Bananas         11
# Bread           11
# Cereal          11
# Cheese          11
# Eggs            11
# Ground Beef     11
# Milk            11
# Onions          11
# Orange Juice    11
# Pasta           11
# Rice            11
# Salmon          11
# Tomatoes        11
# Yogurt          11
# Name: aisle, dtype: int64

# %%
# Out:
# 11
